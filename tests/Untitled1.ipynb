# %%
import sys
sys.path.append('../')

# %%
from src.config import DB_CONFIG
from src.model.eq_accountant import EQAccountant
from src.model.t24_accountant import T24Accountant

# %%
eq_accountant = EQAccountant(DB_CONFIG)
t24_accountant = T24Accountant(DB_CONFIG)
# Out:
# 2025-06-17 08:25:58,581 - INFO - EQAccountant initialized with logging enabled: True
# 2025-06-17 08:25:58,600 - INFO - T24Accountant initialized with logging enabled: True

# %%
eq_account = '5820061625500'
t24_account = '2010284298'
year = '2024'

# %%
t24_accountant.get_accountant_transactions(t24_account, year)
# Out:
# 2025-06-17 08:26:01,495 - INFO - Starting to retrieve T24 accountant's transactions for account: 2010284298, year: 2024
# Connection established successfully.
# 2025-06-17 08:26:49,629 - INFO - Successfully executed query:
#             SELECT
#                 T24_ACCOUNTANT.ACCOUNT_NUMBER AS T24_ACCOUNT,
#                 --EQ_T24.ALTERNATIVE_NUMBER AS EQ_ACCOUNT,
#                 'NA' AS EQ_ACCOUNT,
#                 --EQ_ORACLE.NEEAN AS ORACLE_ACCOUNT,
#                 'NA' AS ORACLE_ACCOUNT,
#                 T24_ACCOUNTANT.TRANS_REFERENCE AS TRANSACTION_REF,
#                 'NA' AS TRANSACTION_SEQ,
#                 T24_ACCOUNTANT.VALUE_DATE AS TRANSACTION_DATE,
#                 T24_ACCOUNTANT.SYSTEM_DATE_TIME AS TRANSACTION_DATE_TS,
#                 T24_ACCOUNTANT.CURRENCY AS TRANSACTION_CURRENCY,
#                 T24_ACCOUNTANT.AMOUNT_LCY AS TRANSACTION_AMOUNT_LCY,
#                 T24_ACCOUNTANT.AMOUNT_FCY AS TRANSACTION_AMOUNT_FCY,
# ...

# %%
t24_accountant.accountant_transactions
# Out:
#     T24_ACCOUNT EQ_ACCOUNT ORACLE_ACCOUNT   TRANSACTION_REF TRANSACTION_SEQ  \
# 0    2010284298         NA             NA  FT241490RDSX0PLS              NA
# 1    2010284298         NA             NA  FT2403106TKHXT1R              NA
# 2    2010284298         NA             NA  FT2400805FHHY13M              NA
# 3    2010284298         NA             NA  FT240290NDW8XJKD              NA
# 4    2010284298         NA             NA  FT240261046DBY35              NA
# ..          ...        ...            ...               ...             ...
# 151  2010284298         NA             NA  FT2433011S5WK1PR              NA
# 152  2010284298         NA             NA  FT243090XM57X0J7              NA
# 153  2010284298         NA             NA  FT2436011G6THWPP              NA
# 154  2010284298         NA             NA  FT243410GY8SSXXT              NA
# 155  2010284298         NA             NA  FT2435513XC27HQS              NA
#
# ...

# %%
eq_accountant.get_accountant_transactions(eq_account, year)
# Out:
# 2025-06-17 08:28:27,231 - INFO - Starting to retrieve accountant's transactions for account: 5820061625500, year: 2024
# Connection established successfully.
# 2025-06-17 08:28:55,861 - INFO - Successfully executed query:
#             SELECT
#                 TRIM(EQ_T24.GLOBUS_ACCT_NUMBER) AS T24_ACCOUNT,
#                 TRIM(EQ_T24.ALTERNATIVE_NUMBER) AS EQ_ACCOUNT,
#                 TRIM(EQ_ORACLE.NEEAN) AS ORACLE_ACCOUNT,
#                 TRIM(CAST(EQ_ACCOUNTANT.SADRF AS VARCHAR)) AS TRANSACTION_REF,
#                 EQ_ACCOUNTANT.SAPSQ AS TRANSACTION_SEQ,
#                 TRIM(CAST(EQ_ACCOUNTANT.SAPOD AS VARCHAR)) AS TRANSACTION_DATE,
#                 FORMAT(EQ_ACCOUNTANT.SATSTP, 'yyyy-MM-dd HH.mm') AS TRANSACTION_DATE_TS,
#                 EQ_ACCOUNTANT.SACCY AS TRANSACTION_CURRENCY,
#                 EQ_ACCOUNTANT.SAAMA / POWER(10, CURRENCY.NO_OF_DECIMALS) AS TRANSACTION_AMOUNT,
#                 EQ_ACCOUNTANT.SATCD AS TRANSACTION_CODE_ATB,
# ...

# %%
t24_accountant.accountant_transactions.loc[ t24_accountant.accountant_transactions['APP_SOURCE_CODE'] == 'TT']
# Out:
#    T24_ACCOUNT EQ_ACCOUNT ORACLE_ACCOUNT TRANSACTION_REF TRANSACTION_SEQ  \
# 34  2010284298         NA             NA    TT242749T9C0              NA
# 70  2010284298         NA             NA    TT242905FRKJ              NA
#
#    TRANSACTION_DATE TRANSACTION_DATE_TS TRANSACTION_CURRENCY  \
# 34         20240930   20240930115914197                  TND
# 70         20241016   20241016120543094                  TND
#
#    TRANSACTION_AMOUNT_LCY TRANSACTION_AMOUNT_FCY TRANSACTION_AMOUNT  \
# 34              -2500.000                   None                 NA
# 70              -3300.000                   None                 NA
#
#    TRANSACTION_CODE_ATB TRANSACTION_DESC_ATB APP_SOURCE_CODE ACCOUNTANT_SOURCE
# 34                 1013                   NA              TT               T24
# 70                 1013                   NA              TT               T24

# %%
eq_accountant.accountant_transactions.loc[ eq_accountant.accountant_transactions['APP_SOURCE_CODE'] == 'T24TL']
# Out:
#     T24_ACCOUNT     EQ_ACCOUNT ORACLE_ACCOUNT TRANSACTION_REF TRANSACTION_SEQ  \
# 118  2010284298  5820061625500  0201119826975    TT242905FRKJ             441
# 142  2010284298  5820061625500  0201119826975    TT242749T9C0             567
#
#     TRANSACTION_DATE TRANSACTION_DATE_TS TRANSACTION_CURRENCY  \
# 118          1241016                None                  TND
# 142          1240930                None                  TND
#
#     TRANSACTION_AMOUNT TRANSACTION_CODE_ATB          TRANSACTION_DESC_ATB  \
# 118   -3300.0000000000                  067  Retrait Especes  Meme Agence
# 142   -2500.0000000000                  067  Retrait Especes  Meme Agence
#
#     APP_SOURCE_CODE ACCOUNTANT_SOURCE
# 118           T24TL                EQ
# 142           T24TL                EQ

# %%
import pandas as pd

# %%
eq_accountant.accountant_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   T24_ACCOUNT           185 non-null    object
#  1   EQ_ACCOUNT            185 non-null    object
#  2   ORACLE_ACCOUNT        185 non-null    object
#  3   TRANSACTION_REF       185 non-null    object
#  4   TRANSACTION_SEQ       185 non-null    object
#  5   TRANSACTION_DATE      185 non-null    object
#  6   TRANSACTION_DATE_TS   85 non-null     object
#  7   TRANSACTION_CURRENCY  185 non-null    object
#  8   TRANSACTION_AMOUNT    185 non-null    object
#  9   TRANSACTION_CODE_ATB  185 non-null    object
#  10  TRANSACTION_DESC_ATB  185 non-null    object
#  11  APP_SOURCE_CODE       185 non-null    object
#  12  ACCOUNTANT_SOURCE     185 non-null    object
# dtypes: object(13)
# memory usage: 18.9+ KB

# %%
pd.concat(
    [eq_accountant.accountant_transactions.loc[ eq_accountant.accountant_transactions['APP_SOURCE_CODE'] != 'T24TL'],
     t24_accountant.accountant_transactions.loc[ t24_accountant.accountant_transactions['APP_SOURCE_CODE'] == 'TT']],
    ignore_index=True
)[['T24_ACCOUNT', 'APP_SOURCE_CODE', 'TRANSACTION_CODE_ATB', 'TRANSACTION_DATE', 'TRANSACTION_REF', 'TRANSACTION_SEQ', 'TRANSACTION_CURRENCY', 'TRANSACTION_AMOUNT', 'TRANSACTION_AMOUNT_LCY', 'TRANSACTION_AMOUNT_FCY']]
# Out:
#     T24_ACCOUNT APP_SOURCE_CODE TRANSACTION_CODE_ATB TRANSACTION_DATE  \
# 0    2010284298            @@O2                  427          1240108
# 1    2010284298            @@O2                  427          1240108
# 2    2010284298            @@O2                  439          1240108
# 3    2010284298            @@O2                  427          1240112
# 4    2010284298           DRHTR                  010          1240625
# ..          ...             ...                  ...              ...
# 180  2010284298            @@O2                  427          1241212
# 181  2010284298           HR000                  512          1241227
# 182  2010284298           HR000                  135          1241227
# 183  2010284298              TT                 1013         20240930
# 184  2010284298              TT                 1013         20241016
#
#     TRANSACTION_REF TRANSACTION_SEQ TRANSACTION_CURRENCY TRANSACTION_AMOUNT  \
# ...

# %%
eq_accountant.accountant_transactions.columns
# Out:
# Index(['T24_ACCOUNT', 'EQ_ACCOUNT', 'ORACLE_ACCOUNT', 'TRANSACTION_REF',
#        'TRANSACTION_SEQ', 'TRANSACTION_DATE', 'TRANSACTION_DATE_TS',
#        'TRANSACTION_CURRENCY', 'TRANSACTION_AMOUNT', 'TRANSACTION_CODE_ATB',
#        'TRANSACTION_DESC_ATB', 'APP_SOURCE_CODE', 'ACCOUNTANT_SOURCE'],
#       dtype='object')

# %%
t24_accountant.accountant_transactions.columns
# Out:
# Index(['T24_ACCOUNT', 'EQ_ACCOUNT', 'ORACLE_ACCOUNT', 'TRANSACTION_REF',
#        'TRANSACTION_SEQ', 'TRANSACTION_DATE', 'TRANSACTION_DATE_TS',
#        'TRANSACTION_CURRENCY', 'TRANSACTION_AMOUNT_LCY',
#        'TRANSACTION_AMOUNT_FCY', 'TRANSACTION_AMOUNT', 'TRANSACTION_CODE_ATB',
#        'TRANSACTION_DESC_ATB', 'APP_SOURCE_CODE', 'ACCOUNTANT_SOURCE'],
#       dtype='object')

# %%
pd.concat(
    [eq_accountant.accountant_transactions.loc[ eq_accountant.accountant_transactions['APP_SOURCE_CODE'] != 'T24TL'],
     t24_accountant.accountant_transactions.loc[ t24_accountant.accountant_transactions['APP_SOURCE_CODE'] == 'TT']],
    ignore_index=True
).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   T24_ACCOUNT             185 non-null    object
#  1   EQ_ACCOUNT              185 non-null    object
#  2   ORACLE_ACCOUNT          185 non-null    object
#  3   TRANSACTION_REF         185 non-null    object
#  4   TRANSACTION_SEQ         185 non-null    object
#  5   TRANSACTION_DATE        185 non-null    object
#  6   TRANSACTION_DATE_TS     87 non-null     object
#  7   TRANSACTION_CURRENCY    185 non-null    object
#  8   TRANSACTION_AMOUNT      185 non-null    object
#  9   TRANSACTION_CODE_ATB    185 non-null    object
#  10  TRANSACTION_DESC_ATB    185 non-null    object
#  11  APP_SOURCE_CODE         185 non-null    object
#  12  ACCOUNTANT_SOURCE       185 non-null    object
#  13  TRANSACTION_AMOUNT_LCY  2 non-null      object
# ...
